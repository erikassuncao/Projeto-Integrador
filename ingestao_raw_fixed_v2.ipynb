# %%
# pip install tqdm

# %%
# pip install progressbar

# %%
# pip install pandas

# %%
# pip install lxml

# %%
import pandas as pd
import requests
import numpy as np
import time
import geopandas as gp
import matplotlib
import matplotlib.pyplot as plt
import lxml
import os
from shapely.geometry import Point
from adjustText import adjust_text
from bs4 import BeautifulSoup
from tqdm import tqdm
from tqdm import trange
from datetime import datetime

# %matplotlib inline

# %%
# URL do arquivo shapefile
url = 'https://geoftp.ibge.gov.br/organizacao_do_territorio/malhas_territoriais/malhas_municipais/municipio_2022/Brasil/BR/BR_Municipios_2022.zip'

# Lendo o arquivo shapefile
geo_brasil = gp.read_file(url)

# %%
geo_brasil = geo_brasil[['geometry','CD_MUN']]

# %%
geo_brasil.head()
# Out:
#                                             geometry   CD_MUN
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...  1100015
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...  1100023
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...  1100031
# 3  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...  1100049
# 4  POLYGON ((-60.82135 -13.11910, -60.81773 -13.1...  1100056

# %%
geo_brasil = gp.GeoDataFrame(geo_brasil)
geo_brasil = geo_brasil.set_geometry('geometry')
# Visualizando as primeiras linhas do dataframe
print(geo_brasil.head())
# Out:
#                                             geometry   CD_MUN
# 0  POLYGON ((-62.00806 -12.13379, -62.00784 -12.2...  1100015
# 1  POLYGON ((-63.17933 -10.13924, -63.17746 -10.1...  1100023
# 2  POLYGON ((-60.52408 -13.32137, -60.37162 -13.3...  1100031
# 3  POLYGON ((-61.35502 -11.50452, -61.35524 -11.5...  1100049
# 4  POLYGON ((-60.82135 -13.11910, -60.81773 -13.1...  1100056

# %%
#soup = BeautifulSoup(requests.get("https://ookla-open-data.s3-us-west-2.amazonaws.com/").content, "lxml")
url = "https://ookla-open-data.s3-us-west-2.amazonaws.com/"
response = requests.get(url)
soup = BeautifulSoup(response.content, "xml")

# %%
table = soup.find_all('Key')
df_table = pd.DataFrame(data=table)
df_table = df_table.rename({0 : 'url'}, axis=1)
df = df_table
df[['tipo_dado','perf','tipo_de_rede','ano','trimestre','last_url']] = df['url'].str.split('/',expand=True)

#ao analisar todas as URLs, pode-se observar que possui dados do tipo parquet e shapefiles
pd.set_option('display.max_rows', None)
df.head(100)
# Out:
#                                                   url   tipo_dado  \
# 0   parquet/performance/type=fixed/year=2019/quart...     parquet
# 1   parquet/performance/type=fixed/year=2019/quart...     parquet
# 2   parquet/performance/type=fixed/year=2019/quart...     parquet
# 3   parquet/performance/type=fixed/year=2019/quart...     parquet
# 4   parquet/performance/type=fixed/year=2020/quart...     parquet
# 5   parquet/performance/type=fixed/year=2020/quart...     parquet
# 6   parquet/performance/type=fixed/year=2020/quart...     parquet
# 7   parquet/performance/type=fixed/year=2020/quart...     parquet
# 8   parquet/performance/type=fixed/year=2021/quart...     parquet
# 9   parquet/performance/type=fixed/year=2021/quart...     parquet
# 10  parquet/performance/type=fixed/year=2021/quart...     parquet
# 11  parquet/performance/type=fixed/year=2021/quart...     parquet
# 12  parquet/performance/type=fixed/year=2022/quart...     parquet
# 13  parquet/performance/type=fixed/year=2022/quart...     parquet
# 14  parquet/performance/type=fixed/year=2022/quart...     parquet
# 15  parquet/performance/type=fixed/year=2022/quart...     parquet
# 16  parquet/performance/type=fixed/year=2023/quart...     parquet
# 17  parquet/performance/type=mobile/year=2019/quar...     parquet
# 18  parquet/performance/type=mobile/year=2019/quar...     parquet
# 19  parquet/performance/type=mobile/year=2019/quar...     parquet
# 20  parquet/performance/type=mobile/year=2019/quar...     parquet
# 21  parquet/performance/type=mobile/year=2020/quar...     parquet
# 22  parquet/performance/type=mobile/year=2020/quar...     parquet
# 23  parquet/performance/type=mobile/year=2020/quar...     parquet
# 24  parquet/performance/type=mobile/year=2020/quar...     parquet
# 25  parquet/performance/type=mobile/year=2021/quar...     parquet
# 26  parquet/performance/type=mobile/year=2021/quar...     parquet
# 27  parquet/performance/type=mobile/year=2021/quar...     parquet
# 28  parquet/performance/type=mobile/year=2021/quar...     parquet
# 29  parquet/performance/type=mobile/year=2022/quar...     parquet
# 30  parquet/performance/type=mobile/year=2022/quar...     parquet
# 31  parquet/performance/type=mobile/year=2022/quar...     parquet
# 32  parquet/performance/type=mobile/year=2022/quar...     parquet
# 33  parquet/performance/type=mobile/year=2023/quar...     parquet
# 34  shapefiles/performance/type=fixed/year=2019/qu...  shapefiles
# 35  shapefiles/performance/type=fixed/year=2019/qu...  shapefiles
# 36  shapefiles/performance/type=fixed/year=2019/qu...  shapefiles
# 37  shapefiles/performance/type=fixed/year=2019/qu...  shapefiles
# 38  shapefiles/performance/type=fixed/year=2020/qu...  shapefiles
# 39  shapefiles/performance/type=fixed/year=2020/qu...  shapefiles
# 40  shapefiles/performance/type=fixed/year=2020/qu...  shapefiles
# 41  shapefiles/performance/type=fixed/year=2020/qu...  shapefiles
# 42  shapefiles/performance/type=fixed/year=2021/qu...  shapefiles
# 43  shapefiles/performance/type=fixed/year=2021/qu...  shapefiles
# 44  shapefiles/performance/type=fixed/year=2021/qu...  shapefiles
# 45  shapefiles/performance/type=fixed/year=2021/qu...  shapefiles
# 46  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles
# 47  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles
# 48  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles
# 49  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles
# 50  shapefiles/performance/type=fixed/year=2023/qu...  shapefiles
# 51  shapefiles/performance/type=mobile/year=2019/q...  shapefiles
# 52  shapefiles/performance/type=mobile/year=2019/q...  shapefiles
# 53  shapefiles/performance/type=mobile/year=2019/q...  shapefiles
# 54  shapefiles/performance/type=mobile/year=2019/q...  shapefiles
# 55  shapefiles/performance/type=mobile/year=2020/q...  shapefiles
# 56  shapefiles/performance/type=mobile/year=2020/q...  shapefiles
# 57  shapefiles/performance/type=mobile/year=2020/q...  shapefiles
# 58  shapefiles/performance/type=mobile/year=2020/q...  shapefiles
# 59  shapefiles/performance/type=mobile/year=2021/q...  shapefiles
# 60  shapefiles/performance/type=mobile/year=2021/q...  shapefiles
# 61  shapefiles/performance/type=mobile/year=2021/q...  shapefiles
# 62  shapefiles/performance/type=mobile/year=2021/q...  shapefiles
# 63  shapefiles/performance/type=mobile/year=2022/q...  shapefiles
# 64  shapefiles/performance/type=mobile/year=2022/q...  shapefiles
# 65  shapefiles/performance/type=mobile/year=2022/q...  shapefiles
# 66  shapefiles/performance/type=mobile/year=2022/q...  shapefiles
# 67  shapefiles/performance/type=mobile/year=2023/q...  shapefiles
#
#            perf tipo_de_rede        ano  trimestre  \
# 0   performance   type=fixed  year=2019  quarter=1
# 1   performance   type=fixed  year=2019  quarter=2
# 2   performance   type=fixed  year=2019  quarter=3
# 3   performance   type=fixed  year=2019  quarter=4
# 4   performance   type=fixed  year=2020  quarter=1
# 5   performance   type=fixed  year=2020  quarter=2
# 6   performance   type=fixed  year=2020  quarter=3
# 7   performance   type=fixed  year=2020  quarter=4
# 8   performance   type=fixed  year=2021  quarter=1
# 9   performance   type=fixed  year=2021  quarter=2
# 10  performance   type=fixed  year=2021  quarter=3
# 11  performance   type=fixed  year=2021  quarter=4
# 12  performance   type=fixed  year=2022  quarter=1
# 13  performance   type=fixed  year=2022  quarter=2
# 14  performance   type=fixed  year=2022  quarter=3
# 15  performance   type=fixed  year=2022  quarter=4
# 16  performance   type=fixed  year=2023  quarter=1
# 17  performance  type=mobile  year=2019  quarter=1
# 18  performance  type=mobile  year=2019  quarter=2
# 19  performance  type=mobile  year=2019  quarter=3
# 20  performance  type=mobile  year=2019  quarter=4
# 21  performance  type=mobile  year=2020  quarter=1
# 22  performance  type=mobile  year=2020  quarter=2
# 23  performance  type=mobile  year=2020  quarter=3
# 24  performance  type=mobile  year=2020  quarter=4
# 25  performance  type=mobile  year=2021  quarter=1
# 26  performance  type=mobile  year=2021  quarter=2
# 27  performance  type=mobile  year=2021  quarter=3
# 28  performance  type=mobile  year=2021  quarter=4
# 29  performance  type=mobile  year=2022  quarter=1
# 30  performance  type=mobile  year=2022  quarter=2
# 31  performance  type=mobile  year=2022  quarter=3
# 32  performance  type=mobile  year=2022  quarter=4
# 33  performance  type=mobile  year=2023  quarter=1
# 34  performance   type=fixed  year=2019  quarter=1
# 35  performance   type=fixed  year=2019  quarter=2
# 36  performance   type=fixed  year=2019  quarter=3
# 37  performance   type=fixed  year=2019  quarter=4
# 38  performance   type=fixed  year=2020  quarter=1
# 39  performance   type=fixed  year=2020  quarter=2
# 40  performance   type=fixed  year=2020  quarter=3
# 41  performance   type=fixed  year=2020  quarter=4
# 42  performance   type=fixed  year=2021  quarter=1
# 43  performance   type=fixed  year=2021  quarter=2
# 44  performance   type=fixed  year=2021  quarter=3
# 45  performance   type=fixed  year=2021  quarter=4
# 46  performance   type=fixed  year=2022  quarter=1
# 47  performance   type=fixed  year=2022  quarter=2
# 48  performance   type=fixed  year=2022  quarter=3
# 49  performance   type=fixed  year=2022  quarter=4
# 50  performance   type=fixed  year=2023  quarter=1
# 51  performance  type=mobile  year=2019  quarter=1
# 52  performance  type=mobile  year=2019  quarter=2
# 53  performance  type=mobile  year=2019  quarter=3
# 54  performance  type=mobile  year=2019  quarter=4
# 55  performance  type=mobile  year=2020  quarter=1
# 56  performance  type=mobile  year=2020  quarter=2
# 57  performance  type=mobile  year=2020  quarter=3
# 58  performance  type=mobile  year=2020  quarter=4
# 59  performance  type=mobile  year=2021  quarter=1
# 60  performance  type=mobile  year=2021  quarter=2
# 61  performance  type=mobile  year=2021  quarter=3
# 62  performance  type=mobile  year=2021  quarter=4
# 63  performance  type=mobile  year=2022  quarter=1
# 64  performance  type=mobile  year=2022  quarter=2
# 65  performance  type=mobile  year=2022  quarter=3
# 66  performance  type=mobile  year=2022  quarter=4
# 67  performance  type=mobile  year=2023  quarter=1
#
#                                        last_url
# 0    2019-01-01_performance_fixed_tiles.parquet
# 1    2019-04-01_performance_fixed_tiles.parquet
# 2    2019-07-01_performance_fixed_tiles.parquet
# 3    2019-10-01_performance_fixed_tiles.parquet
# 4    2020-01-01_performance_fixed_tiles.parquet
# 5    2020-04-01_performance_fixed_tiles.parquet
# 6    2020-07-01_performance_fixed_tiles.parquet
# 7    2020-10-01_performance_fixed_tiles.parquet
# 8    2021-01-01_performance_fixed_tiles.parquet
# 9    2021-04-01_performance_fixed_tiles.parquet
# 10   2021-07-01_performance_fixed_tiles.parquet
# 11   2021-10-01_performance_fixed_tiles.parquet
# 12   2022-01-01_performance_fixed_tiles.parquet
# 13   2022-04-01_performance_fixed_tiles.parquet
# 14   2022-07-01_performance_fixed_tiles.parquet
# 15   2022-10-01_performance_fixed_tiles.parquet
# 16   2023-01-01_performance_fixed_tiles.parquet
# 17  2019-01-01_performance_mobile_tiles.parquet
# 18  2019-04-01_performance_mobile_tiles.parquet
# 19  2019-07-01_performance_mobile_tiles.parquet
# 20  2019-10-01_performance_mobile_tiles.parquet
# 21  2020-01-01_performance_mobile_tiles.parquet
# 22  2020-04-01_performance_mobile_tiles.parquet
# 23  2020-07-01_performance_mobile_tiles.parquet
# 24  2020-10-01_performance_mobile_tiles.parquet
# 25  2021-01-01_performance_mobile_tiles.parquet
# 26  2021-04-01_performance_mobile_tiles.parquet
# 27  2021-07-01_performance_mobile_tiles.parquet
# 28  2021-10-01_performance_mobile_tiles.parquet
# 29  2022-01-01_performance_mobile_tiles.parquet
# 30  2022-04-01_performance_mobile_tiles.parquet
# 31  2022-07-01_performance_mobile_tiles.parquet
# 32  2022-10-01_performance_mobile_tiles.parquet
# 33  2023-01-01_performance_mobile_tiles.parquet
# 34       2019-01-01_performance_fixed_tiles.zip
# 35       2019-04-01_performance_fixed_tiles.zip
# 36       2019-07-01_performance_fixed_tiles.zip
# 37       2019-10-01_performance_fixed_tiles.zip
# 38       2020-01-01_performance_fixed_tiles.zip
# 39       2020-04-01_performance_fixed_tiles.zip
# 40       2020-07-01_performance_fixed_tiles.zip
# 41       2020-10-01_performance_fixed_tiles.zip
# 42       2021-01-01_performance_fixed_tiles.zip
# 43       2021-04-01_performance_fixed_tiles.zip
# 44       2021-07-01_performance_fixed_tiles.zip
# 45       2021-10-01_performance_fixed_tiles.zip
# 46       2022-01-01_performance_fixed_tiles.zip
# 47       2022-04-01_performance_fixed_tiles.zip
# 48       2022-07-01_performance_fixed_tiles.zip
# 49       2022-10-01_performance_fixed_tiles.zip
# 50       2023-01-01_performance_fixed_tiles.zip
# 51      2019-01-01_performance_mobile_tiles.zip
# 52      2019-04-01_performance_mobile_tiles.zip
# 53      2019-07-01_performance_mobile_tiles.zip
# 54      2019-10-01_performance_mobile_tiles.zip
# 55      2020-01-01_performance_mobile_tiles.zip
# 56      2020-04-01_performance_mobile_tiles.zip
# 57      2020-07-01_performance_mobile_tiles.zip
# 58      2020-10-01_performance_mobile_tiles.zip
# 59      2021-01-01_performance_mobile_tiles.zip
# 60      2021-04-01_performance_mobile_tiles.zip
# 61      2021-07-01_performance_mobile_tiles.zip
# 62      2021-10-01_performance_mobile_tiles.zip
# 63      2022-01-01_performance_mobile_tiles.zip
# 64      2022-04-01_performance_mobile_tiles.zip
# 65      2022-07-01_performance_mobile_tiles.zip
# 66      2022-10-01_performance_mobile_tiles.zip
# 67      2023-01-01_performance_mobile_tiles.zip

# %%
#optou-se pela utilização do tipo shapefiles
#filtrando dados shapefiles

df2 = df[df['tipo_dado'].str.contains('shapefiles')]
df2 = df2[df2['ano'].str.contains('2022|2023')]
df2["url_completa"] = "https://ookla-open-data.s3-us-west-2.amazonaws.com/" + df2['url'].astype(str)
df2['last_url'] = df['last_url'].str.split('.').str[0]
df2 = df2.loc[df['tipo_de_rede'] == 'type=fixed']
df2
# Out:
#                                                   url   tipo_dado  \
# 46  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles
# 47  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles
# 48  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles
# 49  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles
# 50  shapefiles/performance/type=fixed/year=2023/qu...  shapefiles
#
#            perf tipo_de_rede        ano  trimestre  \
# 46  performance   type=fixed  year=2022  quarter=1
# 47  performance   type=fixed  year=2022  quarter=2
# 48  performance   type=fixed  year=2022  quarter=3
# 49  performance   type=fixed  year=2022  quarter=4
# 50  performance   type=fixed  year=2023  quarter=1
#
#                               last_url  \
# 46  2022-01-01_performance_fixed_tiles
# 47  2022-04-01_performance_fixed_tiles
# 48  2022-07-01_performance_fixed_tiles
# 49  2022-10-01_performance_fixed_tiles
# 50  2023-01-01_performance_fixed_tiles
#
#                                          url_completa
# 46  https://ookla-open-data.s3-us-west-2.amazonaws...
# 47  https://ookla-open-data.s3-us-west-2.amazonaws...
# 48  https://ookla-open-data.s3-us-west-2.amazonaws...
# 49  https://ookla-open-data.s3-us-west-2.amazonaws...
# 50  https://ookla-open-data.s3-us-west-2.amazonaws...

# %%
lai = pd.read_csv('C:/Users/crash/desktop/log_raw.csv')
lai = lai.rename(columns={'Etapa': 'url_completa'})
lai
# Out:
#          Data                                       url_completa
# 0  2023-05-14  https://ookla-open-data.s3-us-west-2.amazonaws...
# 1  2023-05-14  https://ookla-open-data.s3-us-west-2.amazonaws...
# 2  2023-05-14  https://ookla-open-data.s3-us-west-2.amazonaws...
# 3  2023-05-14  https://ookla-open-data.s3-us-west-2.amazonaws...
# 4  2023-05-14  https://ookla-open-data.s3-us-west-2.amazonaws...
# 5  2023-05-14  https://ookla-open-data.s3-us-west-2.amazonaws...

# %%
#separa apenas os dados que não existem na tabela de log para inserir
diff = pd.merge(df2, lai, on='url_completa', how='left', indicator=True)
para_inserir = diff.loc[diff['_merge'] == 'left_only']
para_inserir.head()
# Out:
#                                                  url   tipo_dado         perf  \
# 0  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles  performance
# 1  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles  performance
# 2  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles  performance
# 3  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles  performance
# 4  shapefiles/performance/type=fixed/year=2023/qu...  shapefiles  performance
#
#   tipo_de_rede        ano  trimestre                            last_url  \
# 0   type=fixed  year=2022  quarter=1  2022-01-01_performance_fixed_tiles
# 1   type=fixed  year=2022  quarter=2  2022-04-01_performance_fixed_tiles
# 2   type=fixed  year=2022  quarter=3  2022-07-01_performance_fixed_tiles
# 3   type=fixed  year=2022  quarter=4  2022-10-01_performance_fixed_tiles
# 4   type=fixed  year=2023  quarter=1  2023-01-01_performance_fixed_tiles
#
#                                         url_completa Data     _merge
# 0  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only
# 1  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only
# 2  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only
# 3  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only
# 4  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only

# %%
for x in para_inserir['url_completa']:
    print(x)
# Out:
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2022/quarter=1/2022-01-01_performance_fixed_tiles.zip
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2022/quarter=2/2022-04-01_performance_fixed_tiles.zip
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2022/quarter=3/2022-07-01_performance_fixed_tiles.zip
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2022/quarter=4/2022-10-01_performance_fixed_tiles.zip
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2023/quarter=1/2023-01-01_performance_fixed_tiles.zip

# %%
para_inserir
# Out:
#                                                  url   tipo_dado         perf  \
# 0  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles  performance
# 1  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles  performance
# 2  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles  performance
# 3  shapefiles/performance/type=fixed/year=2022/qu...  shapefiles  performance
# 4  shapefiles/performance/type=fixed/year=2023/qu...  shapefiles  performance
#
#   tipo_de_rede        ano  trimestre                            last_url  \
# 0   type=fixed  year=2022  quarter=1  2022-01-01_performance_fixed_tiles
# 1   type=fixed  year=2022  quarter=2  2022-04-01_performance_fixed_tiles
# 2   type=fixed  year=2022  quarter=3  2022-07-01_performance_fixed_tiles
# 3   type=fixed  year=2022  quarter=4  2022-10-01_performance_fixed_tiles
# 4   type=fixed  year=2023  quarter=1  2023-01-01_performance_fixed_tiles
#
#                                         url_completa Data     _merge
# 0  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only
# 1  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only
# 2  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only
# 3  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only
# 4  https://ookla-open-data.s3-us-west-2.amazonaws...  NaN  left_only

# %%
# separa apenas os dados que não existem na tabela de log para inserir
# diff = pd.merge(df2, lai, on='url_completa', how='left', indicator=True)
# para_inserir = diff.loc[diff['_merge'] == 'left_only']
# para_inserir.head()

# %%
print(geo_brasil.crs)
# Out:
# EPSG:4674

# %%
import csv
import datetime

# Criando o GeoDataFrame vazio
geo_appended = gp.GeoDataFrame()

# Criando o arquivo de log
with open('log_raw.csv', mode='a', newline='') as log_file:
    log_writer = csv.writer(log_file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

    for x,y in tqdm(zip(para_inserir.last_url,para_inserir.url_completa)):
        print(x)
        print(y)
        raw_new = gp.read_file(y)
        raw_new_2 = raw_new.set_geometry('geometry') # Adicionando esta linha
        print('etapa 1 - Leitura do arquivo - Concluida')
        # filtra dados apenas do Brasil
        raw_new_2 = raw_new_2.to_crs(geo_brasil.crs)
        raw_new_3 = gp.sjoin(raw_new_2, geo_brasil, how="inner", predicate='intersects')
        
        raw_new_3 = raw_new_3.assign(fonte=y)
        raw_new_3
        print('etapa 2 - Adicionando coluna fonte - Concluida')
        # Concatenando o GeoDataFrame com o novo dado
        geo_appended = pd.concat([geo_appended, raw_new_3], ignore_index=True)
        # Adicionando a etapa no arquivo de log
        log_writer.writerow([datetime.date.today(), y])

        del raw_new
        del raw_new_2
        del raw_new_3

# Salvando o GeoDataFrame em um único arquivo shapefile
geo_appended.to_file('raw_speedtest_fixed.shp', driver='ESRI Shapefile')
# Out:
# 0it [00:00, ?it/s]
# 2022-01-01_performance_fixed_tiles
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2022/quarter=1/2022-01-01_performance_fixed_tiles.zip
# etapa 1 - Leitura do arquivo - Concluida
# etapa 2 - Adicionando coluna fonte - Concluida
# 1it [20:08, 1208.69s/it]
# 2022-04-01_performance_fixed_tiles
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2022/quarter=2/2022-04-01_performance_fixed_tiles.zip
# etapa 1 - Leitura do arquivo - Concluida
# etapa 2 - Adicionando coluna fonte - Concluida
# 2it [40:19, 1209.70s/it]
# 2022-07-01_performance_fixed_tiles
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2022/quarter=3/2022-07-01_performance_fixed_tiles.zip
# etapa 1 - Leitura do arquivo - Concluida
# etapa 2 - Adicionando coluna fonte - Concluida
# 3it [59:44, 1189.35s/it]
# 2022-10-01_performance_fixed_tiles
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2022/quarter=4/2022-10-01_performance_fixed_tiles.zip
# etapa 1 - Leitura do arquivo - Concluida
# etapa 2 - Adicionando coluna fonte - Concluida
# 4it [1:18:05, 1154.68s/it]
# 2023-01-01_performance_fixed_tiles
# https://ookla-open-data.s3-us-west-2.amazonaws.com/shapefiles/performance/type=fixed/year=2023/quarter=1/2023-01-01_performance_fixed_tiles.zip
# etapa 1 - Leitura do arquivo - Concluida
# etapa 2 - Adicionando coluna fonte - Concluida
# 5it [1:39:46, 1197.26s/it]
# C:\Users\crash\AppData\Local\Temp\ipykernel_12924\3188724950.py:34: UserWarning: Column names longer than 10 characters will be truncated when saved to ESRI Shapefile.
#   geo_appended.to_file('raw_speedtest_fixed.shp', driver='ESRI Shapefile')

# %%
geo_appended.head()
# Out:
#             quadkey  avg_d_kbps  avg_u_kbps  avg_lat_ms  tests  devices  \
# 0  2110223123011000      157341       56947          13   1095      259
# 1  2110223121232032      184049      107142           4    120       45
# 2  2110223123001110      176971       90063          23    221       52
# 3  2110223121223330      160729       94449           5    105       26
# 4  2110223121233110      167756       63182           9    590      119
#
#                                             geometry  index_right   CD_MUN  \
# 0  POLYGON ((-40.29785 -20.30342, -40.29236 -20.3...         3174  3205309
# 1  POLYGON ((-40.33081 -20.27766, -40.32532 -20.2...         3174  3205309
# 2  POLYGON ((-40.35278 -20.30342, -40.34729 -20.3...         3174  3205309
# 3  POLYGON ((-40.35278 -20.29311, -40.34729 -20.2...         3174  3205309
# 4  POLYGON ((-40.26489 -20.26220, -40.25940 -20.2...         3174  3205309
#
#                                                fonte
# 0  https://ookla-open-data.s3-us-west-2.amazonaws...
# 1  https://ookla-open-data.s3-us-west-2.amazonaws...
# 2  https://ookla-open-data.s3-us-west-2.amazonaws...
# 3  https://ookla-open-data.s3-us-west-2.amazonaws...
# 4  https://ookla-open-data.s3-us-west-2.amazonaws...
